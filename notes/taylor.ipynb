# %%
import numpy as np
from sympy import *
init_printing()

# %%
t = symbols('t')
a_thrust_i = Function('a_Ti')(t)
a_thrust_j = Function('a_Tj')(t)
a_thrust_k = Function('a_Tk')(t)
a_thrust_pcf = Matrix([a_thrust_i, a_thrust_j, a_thrust_k])
y1_hat_i = Function(r'\hat{y}_{1i}')(t)
y1_hat_k = Function(r'\hat{y}_{1k}')(t)
y1_hat_pcf = Matrix([y1_hat_i, 0, y1_hat_k])
v_i = Function('v_i')(t)
v_j = Function('v_j')(t)
v_k = Function('v_k')(t)
v_pcf = Matrix([v_i, v_j, v_k])
v_theta = Function(r'v_{\theta}')(t)
v_hat_j = Function(r'\hat{v}_{j}')(t)
v_hat_k = Function(r'\hat{v}_{k}')(t)
theta_hat_pcf = Matrix([0, v_hat_j, v_hat_k])
y1 = Function(r'y_1')(t)
r = Function('r')(t)
# Out:
#
#
#
#                  2                             2                      2
#                 d                             d                      d
# \hat{v}_{j}(t)⋅───(a_Tj(t)) + \hat{v}_{k}(t)⋅───(a_Tk(t)) + a_Tj(t)⋅───(\hat{v
#                  2                             2                      2
#                dt                            dt                     dt
#
#
#
#
#                       2
#                      d                      d                  d
# }_{j}(t)) + a_Tk(t)⋅───(\hat{v}_{k}(t)) + 2⋅──(\hat{v}_{j}(t))⋅──(a_Tj(t)) + 2
#                       2                     dt                 dt
#                     dt
#
#                                                   3                    2
#                                                  d          d         d
#                                   v_{\theta}(t)⋅───(r(t))   ──(r(t))⋅───(v_{\t
#                                                   3         dt         2
# ...

# %%
v_theta_dot_ex = a_thrust_pcf.dot(theta_hat_pcf) - r.diff(t)*v_theta/r
v_theta_dot_ex.diff(t).diff(t)

v = Function('v')(t)
v_hat_i_ex = r.diff(t)
v_hat_k_ex = 
v_hat_j_ex = sqrt(v**2 - v_hat_i_)
